# %%
import lib.HFS

# %%
HFS.set_Nk(50)
HFS.set_rs(1.0)
HFS.set_ndim(2)
HFS.py_calc_params()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('white')
plt.figure()
HFS.plot_energy()
plt.show()

plt.figure(figsize=(4,4)) 
HFS.plot_1stBZ()
plt.show()
plt.figure()
HFS.plot_exc_hist()
