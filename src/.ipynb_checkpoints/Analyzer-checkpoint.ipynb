# %%
import pyfiles.HFSAnalyzer as HFSAnalyzer
reload(HFSAnalyzer)
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import math
sns.set_style('white')
# %matplotlib inline

df = HFSAnalyzer.directory_to_df()
df = df[:2]

# %%
fig = plt.figure()
fig, axes = HFSAnalyzer.df_ApplyAxplotToRows(df, None, HFSAnalyzer.axplot_1stBZ, 
                                             spec_alpha=0.5, scale=1.2)
fig.set_size_inches(4,4)
plt.tight_layout()
plt.show()

fig = plt.figure()
fig, axes =  HFSAnalyzer.df_ApplyAxplotToRows(df, None, HFSAnalyzer.axplot_exc_hist)
fig.set_size_inches(4,4)
plt.tight_layout()
plt.show()

fig = plt.figure()
fig, axes = HFSAnalyzer.df_ApplyAxplotToRows(df, None, HFSAnalyzer.axplot_convergence)
fig.set_size_inches(4,4)
plt.tight_layout()
plt.show()
