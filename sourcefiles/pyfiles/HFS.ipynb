# %%
from lib import HFS

# %%
HFS.set_Nk(5)
HFS.set_rs(1.2)
HFS.set_ndim(2)
HFS.py_calc_params()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('white')
plt.figure()
HFS.plot_energy()
plt.show()

plt.figure(figsize=(4,4)) 
HFS.plot_1stBZ()
plt.show()
plt.figure()
HFS.plot_exc_hist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3c56f8286d0b> in <module>()
#      11 plt.show()
#      12 plt.figure()
# ---> 13 HFS.plot_exc_hist()
#
# /home/evan/git/HF-Stability/sourcefiles/pyfiles/HFS.pyx in HFS.plot_exc_hist (HFS.cpp:8042)()
#     183
#     184 def plot_exc_hist():
# --> 185     plt.hist(get_exc_energies(), get_Nexc()/30)
#     186     plt.title('Excitation Energy Histogram')
#     187     plt.xlabel('$\epsilon_{vir} - \epsilon_{occ}$ (Hartree)')
#
# /home/evan/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    2963                       histtype=histtype, align=align, orientation=orientation,
#    2964                       rwidth=rwidth, log=log, color=color, label=label,
# ...
